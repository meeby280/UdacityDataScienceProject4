# %% [markdown]
# # 7 Total Possible Groups of Users
#
# 1. [Users that received offers](#r)
#     1. [Users that viewed offers](#rv)
#         1. [Users that completed offers](#rvc)
#         2. [Users that did not complete offers, but still had transactions](#rvt)
#         3. [Users that did not have transactions](#rvn)
#     2. [Users that did not view offers](#rn)
#         1. [Users that completed offers](#rnc)
#         2. [Users that did not complete offers, but still had transactions](#rnt)
#         3. [Users that did not have transactions](#rnn)
# 2. [Users that did not have any offers, only transactions](#only_transactions)
#     - We don't really care about these users since they did not have an offer to respond to to begin with

# %% [markdown]
# # Library Imports

# %%
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# # Loading Cleaned Data

# %%
conn = create_engine('sqlite:///data/starbucks_data.db')

offers = pd.read_sql('SELECT * FROM offers', conn)
offers_wo_chnl = offers.drop(columns=['offer_notification_channel', 'offer_type', 'offer_spend_minimum', 'offer_reward']).drop_duplicates()

interactions = pd.read_sql('SELECT * FROM interactions', conn)

# %% [markdown]
# ## Separating Out Interactions Data
# Here I am separating the user interactions by their event type. These event types are for noting if the user has __received__, __viewed__, or __completed__ an offer. Additionally it notes what __transactions__ the user had.
#
# When receiving an offer, the offer has a duration assigned. The user must complete the offer within this duration in order for it to count as completed.

# %%
base_col_order = ['user_id', 'offer_id', 'intxn_event_type', 'intxn_time', 'intxn_amount', 'intxn_reward']

offer_received = interactions[ interactions['intxn_event_type'] == 'offer received' ].copy().drop(['intxn_amount', 'intxn_reward'], axis=1)
offer_received_cols = [ "received" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_received.columns ]
offer_received.columns = offer_received_cols

offer_received = pd.merge(offer_received, offers_wo_chnl, how='left', on='offer_id')
offer_received['expiration_time'] = offer_received['received_time'] + offer_received['offer_duration']
offer_received = offer_received.drop(columns=['offer_duration'])

offer_viewed = interactions[ interactions['intxn_event_type'] == 'offer viewed' ].copy().drop(['intxn_amount', 'intxn_reward'], axis=1)
offer_viewed_cols = [ "viewed" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_viewed.columns ]
offer_viewed.columns = offer_viewed_cols

offer_completed = interactions[ interactions['intxn_event_type'] == 'offer completed' ].copy().drop(['intxn_amount', 'intxn_reward'], axis=1)
offer_completed_cols = [ "completed" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_completed.columns ]
offer_completed.columns = offer_completed_cols

transactions = interactions[ interactions['intxn_event_type'] == 'transaction' ].copy().drop(['offer_id', 'intxn_reward'], axis=1)
transactions_cols = [ "transaction" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in transactions.columns ]
transactions.columns = transactions_cols

# %% [markdown]
# <a id='r'></a>
# # Users that received offers

# %%
offer_received.head()
# Out:
#                             user_id                          offer_id  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 1  a03223e636434f42ac4c3df47e8bac43  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 2  e2127556f4f64592b11af22de27a7932  2906b810c7d4411798c6938adc9daaa5
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  fafdcd668e3743c1bb461111dcafc2a4
# 4  68617ca6246f4fbc85e91a2a49552598  4d5c57ea9a6940dd891ad53e9dbe8da0
#
#   received_event_type  received_time  offer_reward_vs_spend  expiration_time
# 0      offer received              0                   1.00              168
# 1      offer received              0                   0.25              240
# 2      offer received              0                   0.20              168
# 3      offer received              0                   0.20              240
# 4      offer received              0                   1.00              120

# %% [markdown]
# <a id='rv'></a>
# ## Users that viewed offers

# %%
offer_recv_view = pd.merge( offer_received, offer_viewed, on=['user_id', 'offer_id'], how='left' )
offer_recv_view = offer_recv_view[ ~offer_recv_view['viewed_time'].isna() ]
# Removing duplicates caused by receiving the same offer multiple times and the join including those received offers before the viewed ones
offer_recv_view = offer_recv_view[ offer_recv_view['received_time'] <= offer_recv_view['viewed_time'] ]
offer_recv_view = offer_recv_view[ offer_recv_view['viewed_time'] <= offer_recv_view['expiration_time'] ]
# Removing duplicates caused by viewing the same offer after receiving it another time
offer_recv_view = offer_recv_view.sort_values(['user_id', 'received_time', 'expiration_time', 'viewed_time']).drop_duplicates(subset=['offer_id', 'user_id', 'received_time', 'expiration_time'], keep='first')

offer_recv_view
# Out:
#                                 user_id                          offer_id  \
# 19437  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 35295  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 51166  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 66965  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 20066  00116118485d4dfda04fdbaba9a87b5c  f19421c1d4aa40978ebb69ca19b0e20d
# ...                                 ...                               ...
# 17694  ffff82501cea40309d5fdd7edcca4a07  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 33595  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 49455  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 65289  ffff82501cea40309d5fdd7edcca4a07  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 81024  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
#
#       received_event_type  received_time  offer_reward_vs_spend  \
# 19437      offer received            168                   0.00
# 35295      offer received            336                   0.00
# 51166      offer received            408                   1.00
# 66965      offer received            504                   0.20
# 20066      offer received            168                   1.00
# ...                   ...            ...                    ...
# 17694      offer received            168                   0.25
# 33595      offer received            336                   0.20
# 49455      offer received            408                   0.20
# 65289      offer received            504                   1.00
# 81024      offer received            576                   0.20
#
#        expiration_time viewed_event_type  viewed_time
# 19437              240      offer viewed        192.0
# 35295              432      offer viewed        372.0
# 51166              528      offer viewed        456.0
# 66965              744      offer viewed        540.0
# 20066              288      offer viewed        216.0
# ...                ...               ...          ...
# 17694              408      offer viewed        174.0
# 33595              504      offer viewed        354.0
# 49455              576      offer viewed        414.0
# 65289              672      offer viewed        534.0
# 81024              744      offer viewed        582.0
#
# [56895 rows x 8 columns]

# %% [markdown]
# <a id='rvc'></a>
# ### Users that completed the offer

# %%
offer_recv_view_comp = pd.merge( offer_recv_view, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_recv_view_comp = offer_recv_view_comp[ ~offer_recv_view_comp['completed_time'].isna() ]
# Removing duplicates caused by completing the same offer before receiving it another time
offer_recv_view_comp = offer_recv_view_comp[ offer_recv_view_comp['completed_time'] >= offer_recv_view_comp['received_time'] ]
# Removing duplicates caused by completing the same offer after viewing it another time
offer_recv_view_comp = offer_recv_view_comp[ offer_recv_view_comp['completed_time'] >= offer_recv_view_comp['viewed_time'] ]
offer_recv_view_comp = offer_recv_view_comp[ offer_recv_view_comp['completed_time'] <= offer_recv_view_comp['expiration_time'] ]
# Removing duplicates caused by viewing the same offer after receiving it another time
offer_recv_view_comp = offer_recv_view_comp.sort_values(['user_id', 'received_time', 'viewed_time', 'completed_time']).drop_duplicates(subset=['offer_id', 'user_id', 'received_time', 'viewed_time'], keep='first')

offer_recv_view_comp
# Out:
#                                 user_id                          offer_id  \
# 7      0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 9      0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 10     0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 11     0020c2b971eb4e9188eac86d93036a77  fafdcd668e3743c1bb461111dcafc2a4
# 13     0020c2b971eb4e9188eac86d93036a77  4d5c57ea9a6940dd891ad53e9dbe8da0
# ...                                 ...                               ...
# 65565  fffad4f4828548d1b5583907f2e9906b  f19421c1d4aa40978ebb69ca19b0e20d
# 65567  ffff82501cea40309d5fdd7edcca4a07  fafdcd668e3743c1bb461111dcafc2a4
# 65568  ffff82501cea40309d5fdd7edcca4a07  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 65569  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 65573  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
#
#       received_event_type  received_time  offer_reward_vs_spend  \
# 7          offer received            168                   0.43
# 9          offer received            408                   0.25
# 10         offer received            504                   1.00
# 11         offer received              0                   0.20
# 13         offer received            408                   1.00
# ...                   ...            ...                    ...
# 65565      offer received            408                   1.00
# 65567      offer received              0                   0.20
# 65568      offer received            168                   0.25
# 65569      offer received            336                   0.20
# 65573      offer received            408                   0.20
#
#        expiration_time viewed_event_type  viewed_time completed_event_type  \
# 7                  336      offer viewed        186.0      offer completed
# 9                  648      offer viewed        432.0      offer completed
# 10                 672      offer viewed        516.0      offer completed
# 11                 240      offer viewed         12.0      offer completed
# 13                 528      offer viewed        426.0      offer completed
# ...                ...               ...          ...                  ...
# 65565              528      offer viewed        510.0      offer completed
# 65567              240      offer viewed          6.0      offer completed
# 65568              408      offer viewed        174.0      offer completed
# 65569              504      offer viewed        354.0      offer completed
# 65573              576      offer viewed        414.0      offer completed
#
#        completed_time
# 7               252.0
# 9               576.0
# 10              576.0
# 11               54.0
# 13              510.0
# ...               ...
# 65565           516.0
# 65567            60.0
# 65568           198.0
# 65569           384.0
# 65573           414.0
#
# [23864 rows x 10 columns]

# %%
offer_recv_view_comp.to_sql('offer_recv_view_comp', conn, if_exists='replace', index=False)
# Out:
# 23864

# %% [markdown]
# <a id='rvt'></a>
# ### Users that did not complete the offer

# %%
offer_recv_view_nocomp = pd.merge( offer_recv_view, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_recv_view_nocomp = offer_recv_view_nocomp[ offer_recv_view_nocomp['completed_time'].isna() ]
offer_recv_view_nocomp = pd.merge( offer_recv_view_nocomp, transactions, on=['user_id'], how='left' )
offer_recv_view_nocomp = offer_recv_view_nocomp[ offer_recv_view_nocomp['transaction_time'] > offer_recv_view_nocomp['received_time'] ]
offer_recv_view_nocomp = offer_recv_view_nocomp[ offer_recv_view_nocomp['transaction_time'] > offer_recv_view_nocomp['viewed_time'] ]
offer_recv_view_nocomp = offer_recv_view_nocomp[ offer_recv_view_nocomp['transaction_time'] < offer_recv_view_nocomp['expiration_time'] ]
offer_recv_view_nocomp_agg = offer_recv_view_nocomp.groupby(['user_id', 'offer_id', 'received_event_type', 'viewed_event_type']).agg(
    offer_received_time=('received_time', 'first'),
    offer_expiration_time=('expiration_time', 'first'),
    offer_viewed_time=('viewed_time', 'first'),
    transaction_time=('transaction_time', 'last'),
    transaction_count=('transaction_time', 'count'),
    transaction_sum=('transaction_amount', 'sum')
).reset_index()

offer_recv_view_nocomp_agg
# Out:
#                                 user_id                          offer_id  \
# 0      0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1      0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2      0020ccbbb6d84e358d3414a3ff76cffd  5a8bc65990b245e5a138643cd4eb9837
# 3      003d66b6608740288d6cc97a6903f4f0  3f207df678b143eea3cee63160fa8bed
# 4      003d66b6608740288d6cc97a6903f4f0  5a8bc65990b245e5a138643cd4eb9837
# ...                                 ...                               ...
# 13581  fff3ba4757bd42088c044ca26d73817a  5a8bc65990b245e5a138643cd4eb9837
# 13582  fff7576017104bcc8677a8d63322b5e1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 13583  fff7576017104bcc8677a8d63322b5e1  ae264e3637204a6fb9bb56bc8210ddfd
# 13584  fff8957ea8b240a6b5e634b6ee8eafcf  fafdcd668e3743c1bb461111dcafc2a4
# 13585  fffad4f4828548d1b5583907f2e9906b  5a8bc65990b245e5a138643cd4eb9837
#
#       received_event_type viewed_event_type  offer_received_time  \
# 0          offer received      offer viewed                  336
# 1          offer received      offer viewed                  168
# 2          offer received      offer viewed                  408
# 3          offer received      offer viewed                  336
# 4          offer received      offer viewed                    0
# ...                   ...               ...                  ...
# 13581      offer received      offer viewed                  504
# 13582      offer received      offer viewed                  168
# 13583      offer received      offer viewed                  408
# 13584      offer received      offer viewed                  408
# 13585      offer received      offer viewed                  168
#
#        offer_expiration_time  offer_viewed_time  transaction_time  \
# 0                        432              372.0             414.0
# 1                        240              192.0             228.0
# 2                        480              408.0             462.0
# 3                        432              372.0             402.0
# 4                         72               36.0              66.0
# ...                      ...                ...               ...
# 13581                    576              540.0             552.0
# 13582                    288              180.0             276.0
# 13583                    576              414.0             558.0
# 13584                    648              432.0             576.0
# 13585                    240              168.0             198.0
#
#        transaction_count  transaction_sum
# 0                      1             8.57
# 1                      1            22.16
# 2                      4            58.87
# 3                      2             9.60
# 4                      1             0.44
# ...                  ...              ...
# 13581                  1            26.09
# 13582                  2            10.50
# 13583                  1             2.08
# 13584                  3             8.09
# 13585                  1             5.63
#
# [13586 rows x 10 columns]

# %%
offer_recv_view_nocomp.to_sql('offer_recv_view_nocomp', conn, if_exists='replace', index=False)
# Out:
# 30655

# %% [markdown]
# <a id='rvn'></a>
# ### Users that did not have transactions

# %%
offer_recv_view_notrans = pd.merge( offer_recv_view, transactions, on=['user_id'], how='left' )
offer_recv_view_notrans = offer_recv_view_notrans[ offer_recv_view_notrans['transaction_time'].isna() ]
offer_recv_view_notrans = offer_recv_view_notrans[ offer_recv_view_notrans['viewed_time'] < offer_recv_view_notrans['expiration_time'] ]

offer_recv_view_notrans
# Out:
#                                  user_id                          offer_id  \
# 3123    01d7da27b8934ba1b3602a0153e4415f  5a8bc65990b245e5a138643cd4eb9837
# 3124    01d7da27b8934ba1b3602a0153e4415f  fafdcd668e3743c1bb461111dcafc2a4
# 3125    01d7da27b8934ba1b3602a0153e4415f  5a8bc65990b245e5a138643cd4eb9837
# 3126    01d7da27b8934ba1b3602a0153e4415f  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 5524    031387fa9cfd47e88f4e4b4b4cb71925  fafdcd668e3743c1bb461111dcafc2a4
# ...                                  ...                               ...
# 489414  ffd810f301ad42d6bfe98c4ba6ee4125  f19421c1d4aa40978ebb69ca19b0e20d
# 489415  ffd810f301ad42d6bfe98c4ba6ee4125  3f207df678b143eea3cee63160fa8bed
# 489416  ffd810f301ad42d6bfe98c4ba6ee4125  2906b810c7d4411798c6938adc9daaa5
# 489517  ffed75d3abc64b488982f50ed12878b5  4d5c57ea9a6940dd891ad53e9dbe8da0
# 489518  ffed75d3abc64b488982f50ed12878b5  ae264e3637204a6fb9bb56bc8210ddfd
#
#        received_event_type  received_time  offer_reward_vs_spend  \
# 3123        offer received            168                    0.0
# 3124        offer received            336                    0.2
# 3125        offer received            408                    0.0
# 3126        offer received            576                    1.0
# 5524        offer received              0                    0.2
# ...                    ...            ...                    ...
# 489414      offer received              0                    1.0
# 489415      offer received            336                    0.0
# 489416      offer received            408                    0.2
# 489517      offer received              0                    1.0
# 489518      offer received            336                    1.0
#
#         expiration_time viewed_event_type  viewed_time transaction_event_type  \
# 3123                240      offer viewed        168.0                    NaN
# 3124                576      offer viewed        336.0                    NaN
# 3125                480      offer viewed        414.0                    NaN
# 3126                744      offer viewed        666.0                    NaN
# 5524                240      offer viewed          6.0                    NaN
# ...                 ...               ...          ...                    ...
# 489414              120      offer viewed         12.0                    NaN
# 489415              432      offer viewed        342.0                    NaN
# 489416              576      offer viewed        492.0                    NaN
# 489517              120      offer viewed         18.0                    NaN
# 489518              504      offer viewed        348.0                    NaN
#
#         transaction_time  transaction_amount
# 3123                 NaN                 NaN
# 3124                 NaN                 NaN
# 3125                 NaN                 NaN
# 3126                 NaN                 NaN
# 5524                 NaN                 NaN
# ...                  ...                 ...
# 489414               NaN                 NaN
# 489415               NaN                 NaN
# 489416               NaN                 NaN
# 489517               NaN                 NaN
# 489518               NaN                 NaN
#
# [1467 rows x 11 columns]

# %% [markdown]
# <a id='rn'></a>
# ## Users that did not view offers
#
# Don't care about being specific about these users. Just need to know that they did not respond to the offer sent to them

# %%
offer_recv_noview = pd.merge( offer_received, offer_viewed, on=['user_id', 'offer_id'], how='left' )
offer_recv_noview = offer_recv_noview[ offer_recv_noview['viewed_time'].isna() ]

display(offer_recv_noview)
# Out:
#                                 user_id                          offer_id  \
# 11     2eeac8d8feae4a8cad5a6af0499a211d  3f207df678b143eea3cee63160fa8bed
# 26     65aba5c617294649aeb624da249e1ee5  2906b810c7d4411798c6938adc9daaa5
# 29     868317b9be554cb18e50bc68484749a2  2906b810c7d4411798c6938adc9daaa5
# 32     4beeb3ed64dd4898b0edf2f6b67426d3  2906b810c7d4411798c6938adc9daaa5
# 34     25c906289d154b66bf579693f89481c9  2906b810c7d4411798c6938adc9daaa5
# ...                                 ...                               ...
# 95306  97ee6e7a12fe4064b260fa48bdd0330f  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 95307  bf3069b178fe40d789dd027901bc406b  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 95310  f653cf2d8bba42d0a53c2937ee2e5893  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 95317  cb23b66c56f64b109d673d5e56574529  2906b810c7d4411798c6938adc9daaa5
# 95320  e4052622e5ba45a8b96b59aba68cf068  3f207df678b143eea3cee63160fa8bed
#
#       received_event_type  received_time  offer_reward_vs_spend  \
# 11         offer received              0                   0.00
# 26         offer received              0                   0.20
# 29         offer received              0                   0.20
# 32         offer received              0                   0.20
# 34         offer received              0                   0.20
# ...                   ...            ...                    ...
# 95306      offer received            576                   1.00
# 95307      offer received            576                   0.25
# 95310      offer received            576                   1.00
# 95317      offer received            576                   0.20
# 95320      offer received            576                   0.00
#
#        expiration_time viewed_event_type  viewed_time
# 11                  96               NaN          NaN
# 26                 168               NaN          NaN
# 29                 168               NaN          NaN
# 32                 168               NaN          NaN
# 34                 168               NaN          NaN
# ...                ...               ...          ...
# 95306              744               NaN          NaN
# 95307              816               NaN          NaN
# 95310              744               NaN          NaN
# 95317              744               NaN          NaN
# 95320              672               NaN          NaN
#
# [15992 rows x 8 columns]

# %% [markdown]
# <a id='rnc'></a>
# ### Users that completed the offer

# %%
offer_recv_noview_comp = pd.merge( offer_recv_noview, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_recv_noview_comp = offer_recv_noview_comp[ ~offer_recv_noview_comp['completed_time'].isna() ]
offer_recv_noview_comp = offer_recv_noview_comp[ offer_recv_noview_comp['completed_time'] < offer_recv_noview_comp['expiration_time'] ]

offer_recv_noview_comp
# Out:
#                                 user_id                          offer_id  \
# 2      868317b9be554cb18e50bc68484749a2  2906b810c7d4411798c6938adc9daaa5
# 3      4beeb3ed64dd4898b0edf2f6b67426d3  2906b810c7d4411798c6938adc9daaa5
# 13     88baa20c29a94178a43a7d68e5f039d4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 18     2481f1fcfbcb4b288e5a03af02d95373  2906b810c7d4411798c6938adc9daaa5
# 25     bf2c086d4c4049289df1e0c8ea08f55c  9b98b8c7a33c4b65b9aebfe6a799e6d9
# ...                                 ...                               ...
# 16658  3b34800e101b4f6d90ec2b2f8f969013  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 16659  ef205cec5dd44fa19e7f0fad2b8a2e2b  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 16662  4b02006a03994e368ec5e3ac0bcccfe1  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 16673  f653cf2d8bba42d0a53c2937ee2e5893  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 16674  cb23b66c56f64b109d673d5e56574529  2906b810c7d4411798c6938adc9daaa5
#
#       received_event_type  received_time  offer_reward_vs_spend  \
# 2          offer received              0                   0.20
# 3          offer received              0                   0.20
# 13         offer received              0                   0.25
# 18         offer received              0                   0.20
# 25         offer received              0                   1.00
# ...                   ...            ...                    ...
# 16658      offer received            576                   1.00
# 16659      offer received            576                   1.00
# 16662      offer received            576                   1.00
# 16673      offer received            576                   1.00
# 16674      offer received            576                   0.20
#
#        expiration_time viewed_event_type  viewed_time completed_event_type  \
# 2                  168               NaN          NaN      offer completed
# 3                  168               NaN          NaN      offer completed
# 13                 240               NaN          NaN      offer completed
# 18                 168               NaN          NaN      offer completed
# 25                 168               NaN          NaN      offer completed
# ...                ...               ...          ...                  ...
# 16658              744               NaN          NaN      offer completed
# 16659              744               NaN          NaN      offer completed
# 16662              744               NaN          NaN      offer completed
# 16673              744               NaN          NaN      offer completed
# 16674              744               NaN          NaN      offer completed
#
#        completed_time
# 2               132.0
# 3               120.0
# 13              132.0
# 18                0.0
# 25              156.0
# ...               ...
# 16658           654.0
# 16659           582.0
# 16662           582.0
# 16673           630.0
# 16674           156.0
#
# [5369 rows x 10 columns]

# %% [markdown]
# <a id='rnv'></a>
# ### Users that did not complete the offer

# %%
offer_recv_noview_nocomp = pd.merge( offer_recv_noview, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_recv_noview_nocomp = offer_recv_noview_nocomp[ offer_recv_noview_nocomp['completed_event_type'].isna() ]
offer_recv_noview_nocomp = pd.merge( offer_recv_noview_nocomp, transactions, on=['user_id'], how='left' )
offer_recv_noview_nocomp = offer_recv_noview_nocomp[ offer_recv_noview_nocomp['received_time'] < offer_recv_noview_nocomp['transaction_time'] ]
offer_recv_noview_nocomp = offer_recv_noview_nocomp[ offer_recv_noview_nocomp['transaction_time'] < offer_recv_noview_nocomp['expiration_time'] ]

display(offer_recv_noview_nocomp)
# Out:
#                                 user_id                          offer_id  \
# 4      65aba5c617294649aeb624da249e1ee5  2906b810c7d4411798c6938adc9daaa5
# 5      65aba5c617294649aeb624da249e1ee5  2906b810c7d4411798c6938adc9daaa5
# 33     39dbcf43e24d41f4bbf0f134157e0e1e  ae264e3637204a6fb9bb56bc8210ddfd
# 53     488773cae11f4b71875bfccd4e3e99f2  2906b810c7d4411798c6938adc9daaa5
# 64     1827da57bb924833a6f73c79b5f2bbc5  9b98b8c7a33c4b65b9aebfe6a799e6d9
# ...                                 ...                               ...
# 76229  ff737c250d2343729ade04c4f6eb1001  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 76230  ff737c250d2343729ade04c4f6eb1001  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 76231  ff737c250d2343729ade04c4f6eb1001  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 76235  97ee6e7a12fe4064b260fa48bdd0330f  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 76239  bf3069b178fe40d789dd027901bc406b  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#       received_event_type  received_time  offer_reward_vs_spend  \
# 4          offer received              0                   0.20
# 5          offer received              0                   0.20
# 33         offer received              0                   1.00
# 53         offer received              0                   0.20
# 64         offer received              0                   1.00
# ...                   ...            ...                    ...
# 76229      offer received            576                   0.25
# 76230      offer received            576                   0.25
# 76231      offer received            576                   0.25
# 76235      offer received            576                   1.00
# 76239      offer received            576                   0.25
#
#        expiration_time viewed_event_type  viewed_time completed_event_type  \
# 4                  168               NaN          NaN                  NaN
# 5                  168               NaN          NaN                  NaN
# 33                 168               NaN          NaN                  NaN
# 53                 168               NaN          NaN                  NaN
# 64                 168               NaN          NaN                  NaN
# ...                ...               ...          ...                  ...
# 76229              816               NaN          NaN                  NaN
# 76230              816               NaN          NaN                  NaN
# 76231              816               NaN          NaN                  NaN
# 76235              744               NaN          NaN                  NaN
# 76239              816               NaN          NaN                  NaN
#
#        completed_time transaction_event_type  transaction_time  \
# 4                 NaN            transaction              66.0
# 5                 NaN            transaction             144.0
# 33                NaN            transaction              90.0
# 53                NaN            transaction              30.0
# 64                NaN            transaction              18.0
# ...               ...                    ...               ...
# 76229             NaN            transaction             624.0
# 76230             NaN            transaction             666.0
# 76231             NaN            transaction             690.0
# 76235             NaN            transaction             702.0
# 76239             NaN            transaction             708.0
#
#        transaction_amount
# 4                    0.74
# 5                    2.73
# 33                   7.59
# 53                   1.69
# 64                   2.31
# ...                   ...
# 76229                0.29
# 76230                4.27
# 76231                2.43
# 76235                4.39
# 76239               19.46
#
# [10773 rows x 13 columns]

# %% [markdown]
# <a id='rnn'></a>
# ### Users that did not have transactions

# %%
offer_recv_noview_notrans = pd.merge( offer_recv_noview, transactions, on=['user_id'], how='left' )
offer_recv_noview_notrans = offer_recv_noview_notrans[ offer_recv_noview_notrans['transaction_time'].isna() ]
offer_recv_noview_notrans = offer_recv_noview_notrans[ offer_recv_noview_notrans['viewed_time'] < offer_recv_noview_notrans['expiration_time'] ]

offer_recv_noview_notrans
# Out:
# Empty DataFrame
# Columns: [user_id, offer_id, received_event_type, received_time, offer_reward_vs_spend, expiration_time, viewed_event_type, viewed_time, transaction_event_type, transaction_time, transaction_amount]
# Index: []

# %% [markdown]
# <a id='only_transactions'></a>
# # Users with only Transactions
# Not necessary for our evaluation

# %%
transactions_no_promos = pd.merge( transactions, offer_received, on='user_id', how='left' )
transactions_no_promos = transactions_no_promos[ transactions_no_promos['offer_id'].isna() ]

transactions_no_promos
# Out:
#                                  user_id transaction_event_type  \
# 4096    eb540099db834cf59001f83a4561aef3            transaction
# 14148   12ede229379747bd8d74ccdc20097ca3            transaction
# 124269  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 166666  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 238452  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 244267  eb540099db834cf59001f83a4561aef3            transaction
# 248661  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 250562  12ede229379747bd8d74ccdc20097ca3            transaction
# 254212  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 294458  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 321897  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 366987  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 450173  eb540099db834cf59001f83a4561aef3            transaction
# 492554  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 501368  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 506836  da7a7c0dcfcb41a8acc7864a53cf60fb            transaction
# 519982  eb540099db834cf59001f83a4561aef3            transaction
# 569706  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 587607  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 587841  12ede229379747bd8d74ccdc20097ca3            transaction
#
#         transaction_time  transaction_amount offer_id received_event_type  \
# 4096                   6                4.74      NaN                 NaN
# 14148                 18               16.62      NaN                 NaN
# 124269               174                0.65      NaN                 NaN
# 166666               222                1.91      NaN                 NaN
# 238452               306               17.51      NaN                 NaN
# 244267               318                5.09      NaN                 NaN
# 248661               324               22.75      NaN                 NaN
# 250562               324               27.60      NaN                 NaN
# 254212               330               28.70      NaN                 NaN
# 294458               378               27.20      NaN                 NaN
# 321897               408                1.25      NaN                 NaN
# 366987               444               11.53      NaN                 NaN
# 450173               528                7.40      NaN                 NaN
# 492554               570                3.14      NaN                 NaN
# 501368               576               17.67      NaN                 NaN
# 506836               582                0.35      NaN                 NaN
# 519982               594                8.78      NaN                 NaN
# 569706               636                9.72      NaN                 NaN
# 587607               654               18.97      NaN                 NaN
# 587841               654               19.03      NaN                 NaN
#
#         received_time  offer_reward_vs_spend  expiration_time
# 4096              NaN                    NaN              NaN
# 14148             NaN                    NaN              NaN
# 124269            NaN                    NaN              NaN
# 166666            NaN                    NaN              NaN
# 238452            NaN                    NaN              NaN
# 244267            NaN                    NaN              NaN
# 248661            NaN                    NaN              NaN
# 250562            NaN                    NaN              NaN
# 254212            NaN                    NaN              NaN
# 294458            NaN                    NaN              NaN
# 321897            NaN                    NaN              NaN
# 366987            NaN                    NaN              NaN
# 450173            NaN                    NaN              NaN
# 492554            NaN                    NaN              NaN
# 501368            NaN                    NaN              NaN
# 506836            NaN                    NaN              NaN
# 519982            NaN                    NaN              NaN
# 569706            NaN                    NaN              NaN
# 587607            NaN                    NaN              NaN
# 587841            NaN                    NaN              NaN
