# %%
import pandas as pd
import numpy as np

from functools import reduce

from sqlalchemy import create_engine

from datetime import date

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 7 Total Possible Groups of Users
#
# 1. [Users that did not have any offers, only transactions](#only_transactions)
# 2. [Users that received offers](#r)
#     1. [Users that viewed offers](#rv)
#         1. [Users that completed offers](#rvc)
#         2. [Users that did not complete offers, but still had transactions](#rvt)
#         3. [Users that did not have transactions](#rvn)
#     2. [Users that did not view offers](#rn)
#         1. [Users that completed offers](#rnc)
#         2. [Users that did not complete offers, but still had transactions](#rnt)
#         3. [Users that did not have transactions](#rnn)

# %% [markdown]
# Loading data

# %%
conn = create_engine('sqlite:///data/raw_starbucks.db')

# offers.to_sql('offers', conn, if_exists='replace', index=False)
# users.to_sql('users', conn, if_exists='replace', index=False)
# interactions.to_sql('interactions', conn, if_exists='replace', index=False)

offers = pd.read_sql('SELECT * FROM offers', conn)

users = pd.read_sql('SELECT * FROM users', conn)
users['user_age_group'] = users['user_age_group'].fillna('Unknown')
users['user_age_group'] = users['user_age_group'].astype(str)
categories = ['Unknown'] + sorted(users['user_age_group'].unique().tolist())[:-1]
users['user_age_group'] = pd.Categorical(users['user_age_group'], categories=categories, ordered=True)

interactions = pd.read_sql('SELECT * FROM interactions', conn)

# %%
raw_interactions = pd.read_json('data/transcript.json', orient='records', lines=True)

# %%
offer_received = interactions[ interactions['intxn_event_type'] == 'offer received' ].copy().drop(['intxn_amount', 'intxn_reward'], axis=1)
offer_received_cols = [ "received" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_received.columns ]
offer_received.columns = offer_received_cols

offer_viewed = interactions[ interactions['intxn_event_type'] == 'offer viewed' ].copy().drop(['intxn_amount', 'intxn_reward'], axis=1)
offer_viewed_cols = [ "viewed" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_viewed.columns ]
offer_viewed.columns = offer_viewed_cols

offer_completed = interactions[ interactions['intxn_event_type'] == 'offer completed' ].copy().drop(['intxn_amount'], axis=1)
offer_completed_cols = [ "completed" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in offer_completed.columns ]
offer_completed.columns = offer_completed_cols

transactions = interactions[ interactions['intxn_event_type'] == 'transaction' ].copy().drop(['offer_id', 'intxn_reward'], axis=1)
transactions_cols = [ "transaction" + cn.removeprefix('intxn') if 'intxn' in cn else cn for cn in transactions.columns ]
transactions.columns = transactions_cols

# %% [markdown]
# <a id='only_transactions'></a>
# # Users with only Transactions

# %%
transactions_no_promos = pd.merge( transactions, offer_received, on='user_id', how='left' )
transactions_no_promos = transactions_no_promos[ transactions_no_promos['offer_id'].isna() ]

transactions_no_promos
# Out:
#                                  user_id transaction_event_type  \
# 4096    eb540099db834cf59001f83a4561aef3            transaction
# 14148   12ede229379747bd8d74ccdc20097ca3            transaction
# 124269  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 166666  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 238452  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 244267  eb540099db834cf59001f83a4561aef3            transaction
# 248661  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 250562  12ede229379747bd8d74ccdc20097ca3            transaction
# 254212  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 294458  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 321897  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 366987  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 450173  eb540099db834cf59001f83a4561aef3            transaction
# 492554  c6e579c6821c41d1a7a6a9cf936e91bb            transaction
# 501368  3a4874d8f0ef42b9a1b72294902afea9            transaction
# 506836  da7a7c0dcfcb41a8acc7864a53cf60fb            transaction
# 519982  eb540099db834cf59001f83a4561aef3            transaction
# 569706  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 587607  ae8111e7e8cd4b60a8d35c42c1110555            transaction
# 587841  12ede229379747bd8d74ccdc20097ca3            transaction
#
#         transaction_time  transaction_amount received_event_type  \
# 4096                   6                4.74                 NaN
# 14148                 18               16.62                 NaN
# 124269               174                0.65                 NaN
# 166666               222                1.91                 NaN
# 238452               306               17.51                 NaN
# 244267               318                5.09                 NaN
# 248661               324               22.75                 NaN
# 250562               324               27.60                 NaN
# 254212               330               28.70                 NaN
# 294458               378               27.20                 NaN
# 321897               408                1.25                 NaN
# 366987               444               11.53                 NaN
# 450173               528                7.40                 NaN
# 492554               570                3.14                 NaN
# 501368               576               17.67                 NaN
# 506836               582                0.35                 NaN
# 519982               594                8.78                 NaN
# 569706               636                9.72                 NaN
# 587607               654               18.97                 NaN
# 587841               654               19.03                 NaN
#
#         received_time offer_id
# 4096              NaN      NaN
# 14148             NaN      NaN
# 124269            NaN      NaN
# 166666            NaN      NaN
# 238452            NaN      NaN
# 244267            NaN      NaN
# 248661            NaN      NaN
# 250562            NaN      NaN
# 254212            NaN      NaN
# 294458            NaN      NaN
# 321897            NaN      NaN
# 366987            NaN      NaN
# 450173            NaN      NaN
# 492554            NaN      NaN
# 501368            NaN      NaN
# 506836            NaN      NaN
# 519982            NaN      NaN
# 569706            NaN      NaN
# 587607            NaN      NaN
# 587841            NaN      NaN

# %% [markdown]
# <a id='r'></a>
# # Users that received offers

# %%
offer_received.head()
# Out:
#                             user_id received_event_type  received_time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef      offer received              0
# 1  a03223e636434f42ac4c3df47e8bac43      offer received              0
# 2  e2127556f4f64592b11af22de27a7932      offer received              0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586      offer received              0
# 4  68617ca6246f4fbc85e91a2a49552598      offer received              0
#
#                            offer_id
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 2  2906b810c7d4411798c6938adc9daaa5
# 3  fafdcd668e3743c1bb461111dcafc2a4
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0

# %% [markdown]
# <a id='rv'></a>
# ## Users that viewed offers

# %%
offer_received_viewed = pd.merge( offer_received, offer_viewed, on=['user_id', 'offer_id'], how='left' )
offer_received_viewed = offer_received_viewed[ ~offer_received_viewed['viewed_time'].isna() ]
# Removing duplicates caused by receiving the same offer multiple times and the join including those received offers before the viewed ones
offer_received_viewed = offer_received_viewed[ offer_received_viewed['received_time'] <= offer_received_viewed['viewed_time'] ]
# Removing duplicates caused by viewing the same offer after receiving it another time
offer_received_viewed = offer_received_viewed.sort_values(['user_id', 'received_time', 'viewed_time']).drop_duplicates(subset=['offer_id', 'user_id', 'received_time'], keep='first')

offer_received_viewed
# Out:
#                                 user_id received_event_type  received_time  \
# 19437  0009655768c64bdeb2e877511632db8f      offer received            168
# 35295  0009655768c64bdeb2e877511632db8f      offer received            336
# 51166  0009655768c64bdeb2e877511632db8f      offer received            408
# 66965  0009655768c64bdeb2e877511632db8f      offer received            504
# 20066  00116118485d4dfda04fdbaba9a87b5c      offer received            168
# ...                                 ...                 ...            ...
# 17694  ffff82501cea40309d5fdd7edcca4a07      offer received            168
# 33595  ffff82501cea40309d5fdd7edcca4a07      offer received            336
# 49455  ffff82501cea40309d5fdd7edcca4a07      offer received            408
# 65289  ffff82501cea40309d5fdd7edcca4a07      offer received            504
# 81024  ffff82501cea40309d5fdd7edcca4a07      offer received            576
#
#                                offer_id viewed_event_type  viewed_time
# 19437  5a8bc65990b245e5a138643cd4eb9837      offer viewed        192.0
# 35295  3f207df678b143eea3cee63160fa8bed      offer viewed        372.0
# 51166  f19421c1d4aa40978ebb69ca19b0e20d      offer viewed        456.0
# 66965  fafdcd668e3743c1bb461111dcafc2a4      offer viewed        540.0
# 20066  f19421c1d4aa40978ebb69ca19b0e20d      offer viewed        216.0
# ...                                 ...               ...          ...
# 17694  0b1e1539f2cc45b7b9fa7c272da2e1d7      offer viewed        174.0
# 33595  2906b810c7d4411798c6938adc9daaa5      offer viewed        354.0
# 49455  2906b810c7d4411798c6938adc9daaa5      offer viewed        414.0
# 65289  9b98b8c7a33c4b65b9aebfe6a799e6d9      offer viewed        534.0
# 81024  2906b810c7d4411798c6938adc9daaa5      offer viewed        582.0
#
# [58941 rows x 6 columns]

# %% [markdown]
# <a id='rvc'></a>
# ### Users that completed the offer

# %%
offer_received_viewed_completed = pd.merge( offer_received_viewed, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_received_viewed_completed = offer_received_viewed_completed[ ~offer_received_viewed_completed['completed_time'].isna() ]
# Removing duplicates caused by completing the same offer before receiving it another time
offer_received_viewed_completed = offer_received_viewed_completed[ offer_received_viewed_completed['completed_time'] >= offer_received_viewed_completed['received_time'] ]
# Removing duplicates caused by completing the same offer after viewing it another time
offer_received_viewed_completed = offer_received_viewed_completed[ offer_received_viewed_completed['completed_time'] >= offer_received_viewed_completed['viewed_time'] ]
# Removing duplicates caused by viewing the same offer after receiving it another time
offer_received_viewed_completed = offer_received_viewed_completed.sort_values(['user_id', 'received_time', 'viewed_time', 'completed_time']).drop_duplicates(subset=['offer_id', 'user_id', 'received_time', 'viewed_time'], keep='first')

offer_received_viewed_completed
# Out:
#                                 user_id received_event_type  received_time  \
# 7      0011e0d4e6b944f998e987f904e8c1e5      offer received            168
# 9      0011e0d4e6b944f998e987f904e8c1e5      offer received            408
# 10     0011e0d4e6b944f998e987f904e8c1e5      offer received            504
# 11     0020c2b971eb4e9188eac86d93036a77      offer received              0
# 13     0020c2b971eb4e9188eac86d93036a77      offer received            408
# ...                                 ...                 ...            ...
# 67882  fffad4f4828548d1b5583907f2e9906b      offer received            408
# 67884  ffff82501cea40309d5fdd7edcca4a07      offer received              0
# 67885  ffff82501cea40309d5fdd7edcca4a07      offer received            168
# 67886  ffff82501cea40309d5fdd7edcca4a07      offer received            336
# 67890  ffff82501cea40309d5fdd7edcca4a07      offer received            408
#
#                                offer_id viewed_event_type  viewed_time  \
# 7      2298d6c36e964ae4a3e7e9706d1fb8c2      offer viewed        186.0
# 9      0b1e1539f2cc45b7b9fa7c272da2e1d7      offer viewed        432.0
# 10     9b98b8c7a33c4b65b9aebfe6a799e6d9      offer viewed        516.0
# 11     fafdcd668e3743c1bb461111dcafc2a4      offer viewed         12.0
# 13     4d5c57ea9a6940dd891ad53e9dbe8da0      offer viewed        426.0
# ...                                 ...               ...          ...
# 67882  f19421c1d4aa40978ebb69ca19b0e20d      offer viewed        510.0
# 67884  fafdcd668e3743c1bb461111dcafc2a4      offer viewed          6.0
# 67885  0b1e1539f2cc45b7b9fa7c272da2e1d7      offer viewed        174.0
# 67886  2906b810c7d4411798c6938adc9daaa5      offer viewed        354.0
# 67890  2906b810c7d4411798c6938adc9daaa5      offer viewed        414.0
#
#       completed_event_type  completed_time  completed_reward
# 7          offer completed           252.0               3.0
# 9          offer completed           576.0               5.0
# 10         offer completed           576.0               5.0
# 11         offer completed            54.0               2.0
# 13         offer completed           510.0              10.0
# ...                    ...             ...               ...
# 67882      offer completed           516.0               5.0
# 67884      offer completed            60.0               2.0
# 67885      offer completed           198.0               5.0
# 67886      offer completed           384.0               2.0
# 67890      offer completed           414.0               2.0
#
# [25470 rows x 9 columns]

# %%
offer_received_viewed_completed.sort_values(['user_id', 'received_time', 'viewed_time', 'completed_time'])#.drop_duplicates(subset=['offer_id', 'user_id', 'received_time'], keep='first')
# Out:
#                                 user_id received_event_type  received_time  \
# 7      0011e0d4e6b944f998e987f904e8c1e5      offer received            168
# 9      0011e0d4e6b944f998e987f904e8c1e5      offer received            408
# 10     0011e0d4e6b944f998e987f904e8c1e5      offer received            504
# 11     0020c2b971eb4e9188eac86d93036a77      offer received              0
# 12     0020c2b971eb4e9188eac86d93036a77      offer received              0
# ...                                 ...                 ...            ...
# 67886  ffff82501cea40309d5fdd7edcca4a07      offer received            336
# 67887  ffff82501cea40309d5fdd7edcca4a07      offer received            336
# 67888  ffff82501cea40309d5fdd7edcca4a07      offer received            336
# 67890  ffff82501cea40309d5fdd7edcca4a07      offer received            408
# 67891  ffff82501cea40309d5fdd7edcca4a07      offer received            408
#
#                                offer_id viewed_event_type  viewed_time  \
# 7      2298d6c36e964ae4a3e7e9706d1fb8c2      offer viewed        186.0
# 9      0b1e1539f2cc45b7b9fa7c272da2e1d7      offer viewed        432.0
# 10     9b98b8c7a33c4b65b9aebfe6a799e6d9      offer viewed        516.0
# 11     fafdcd668e3743c1bb461111dcafc2a4      offer viewed         12.0
# 12     fafdcd668e3743c1bb461111dcafc2a4      offer viewed         12.0
# ...                                 ...               ...          ...
# 67886  2906b810c7d4411798c6938adc9daaa5      offer viewed        354.0
# 67887  2906b810c7d4411798c6938adc9daaa5      offer viewed        354.0
# 67888  2906b810c7d4411798c6938adc9daaa5      offer viewed        354.0
# 67890  2906b810c7d4411798c6938adc9daaa5      offer viewed        414.0
# 67891  2906b810c7d4411798c6938adc9daaa5      offer viewed        414.0
#
#       completed_event_type  completed_time  completed_reward
# 7          offer completed           252.0               3.0
# 9          offer completed           576.0               5.0
# 10         offer completed           576.0               5.0
# 11         offer completed            54.0               2.0
# 12         offer completed           510.0               2.0
# ...                    ...             ...               ...
# 67886      offer completed           384.0               2.0
# 67887      offer completed           414.0               2.0
# 67888      offer completed           576.0               2.0
# 67890      offer completed           414.0               2.0
# 67891      offer completed           576.0               2.0
#
# [29647 rows x 9 columns]

# %%
offer_received_viewed_completed[ offer_received_viewed_completed['user_id'] == '0020c2b971eb4e9188eac86d93036a77' ].sort_values(['user_id', 'received_time', 'viewed_time', 'completed_time']).drop_duplicates(subset=['offer_id', 'user_id', 'received_time', 'viewed_time'], keep='first')
# Out:
#                              user_id received_event_type  received_time  \
# 11  0020c2b971eb4e9188eac86d93036a77      offer received              0
# 13  0020c2b971eb4e9188eac86d93036a77      offer received            408
#
#                             offer_id viewed_event_type  viewed_time  \
# 11  fafdcd668e3743c1bb461111dcafc2a4      offer viewed         12.0
# 13  4d5c57ea9a6940dd891ad53e9dbe8da0      offer viewed        426.0
#
#    completed_event_type  completed_time  completed_reward
# 11      offer completed            54.0               2.0
# 13      offer completed           510.0              10.0

# %%
test_df = raw_interactions[ (raw_interactions['person'] == '0020c2b971eb4e9188eac86d93036a77') ].sort_values('time')
test_df['offer id'] = test_df['value'].apply(lambda x: x.get('offer id') if isinstance(x, dict) and 'offer id' in x else None)
test_df['offer_id'] = test_df['value'].apply(lambda x: x.get('offer_id') if isinstance(x, dict) and 'offer_id' in x else None)
test_df = test_df[( test_df['offer id'] == 'fafdcd668e3743c1bb461111dcafc2a4') | (test_df['offer_id'] == 'fafdcd668e3743c1bb461111dcafc2a4') ]
test_df.drop(['offer_id', 'offer id'], axis=1, inplace=True)

test_df
# Out:
#                                   person            event  \
# 1889    0020c2b971eb4e9188eac86d93036a77   offer received
# 18431   0020c2b971eb4e9188eac86d93036a77     offer viewed
# 31327   0020c2b971eb4e9188eac86d93036a77  offer completed
# 112698  0020c2b971eb4e9188eac86d93036a77   offer received
# 218936  0020c2b971eb4e9188eac86d93036a77  offer completed
#
#                                                     value  time
# 1889     {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 18431    {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}    12
# 31327   {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...    54
# 112698   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   336
# 218936  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   510

# %% [markdown]
# <a id='rvt'></a>
# ### Users that did not complete the offer

# %%
offer_received_viewed_nocomp = pd.merge( offer_received_viewed, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_received_viewed_nocomp = offer_received_viewed_nocomp[ offer_received_viewed_nocomp['completed_time'].isna() ]
offer_received_viewed_nocomp = pd.merge( offer_received_viewed_nocomp, transactions, on=['user_id'], how='left' )
offer_received_viewed_nocomp = offer_received_viewed_nocomp[ offer_received_viewed_nocomp['transaction_time'] > offer_received_viewed_nocomp['received_time'] ]
offer_received_viewed_nocomp = offer_received_viewed_nocomp[ offer_received_viewed_nocomp['transaction_time'] > offer_received_viewed_nocomp['viewed_time'] ]
offer_received_viewed_nocomp_agg = offer_received_viewed_nocomp.groupby(['user_id', 'offer_id', 'received_event_type', 'viewed_event_type']).agg(
    offer_received_time=('received_time', 'first'),
    offer_viewed_time=('viewed_time', 'first'),
    transaction_time=('transaction_time', 'last'),
    transaction_count=('transaction_time', 'count'),
    transaction_sum=('transaction_amount', 'sum')
).reset_index()

offer_received_viewed_nocomp_agg
# Out:
#                                 user_id                          offer_id  \
# 0      0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1      0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2      00116118485d4dfda04fdbaba9a87b5c  f19421c1d4aa40978ebb69ca19b0e20d
# 3      0011e0d4e6b944f998e987f904e8c1e5  3f207df678b143eea3cee63160fa8bed
# 4      0011e0d4e6b944f998e987f904e8c1e5  5a8bc65990b245e5a138643cd4eb9837
# ...                                 ...                               ...
# 21112  fff3ba4757bd42088c044ca26d73817a  5a8bc65990b245e5a138643cd4eb9837
# 21113  fff7576017104bcc8677a8d63322b5e1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 21114  fff7576017104bcc8677a8d63322b5e1  ae264e3637204a6fb9bb56bc8210ddfd
# 21115  fff8957ea8b240a6b5e634b6ee8eafcf  fafdcd668e3743c1bb461111dcafc2a4
# 21116  fffad4f4828548d1b5583907f2e9906b  5a8bc65990b245e5a138643cd4eb9837
#
#       received_event_type viewed_event_type  offer_received_time  \
# 0          offer received      offer viewed                  336
# 1          offer received      offer viewed                  168
# 2          offer received      offer viewed                  168
# 3          offer received      offer viewed                    0
# 4          offer received      offer viewed                  336
# ...                   ...               ...                  ...
# 21112      offer received      offer viewed                  336
# 21113      offer received      offer viewed                  168
# 21114      offer received      offer viewed                  408
# 21115      offer received      offer viewed                  408
# 21116      offer received      offer viewed                  168
#
#        offer_viewed_time  transaction_time  transaction_count  transaction_sum
# 0                  372.0             696.0                  7           105.44
# 1                  192.0             696.0                  8           127.60
# 2                  216.0             474.0                  3             4.09
# 3                    6.0             654.0                  5            79.46
# 4                  354.0             654.0                  3            54.04
# ...                  ...               ...                ...              ...
# 21112              540.0             552.0                  2            52.18
# 21113              180.0             696.0                  5            24.39
# 21114              414.0             696.0                  3            13.89
# 21115              432.0             576.0                  3             8.09
# 21116              168.0             678.0                  8            62.21
#
# [21117 rows x 9 columns]

# %%
test_offer_ids = offer_received_viewed_nocomp['offer_id'].unique().tolist()

offers[ offers['offer_id'].isin(test_offer_ids) ].sort_values('offer_id')
# Out:
#                             offer_id offer_notification_channel  \
# 14  0b1e1539f2cc45b7b9fa7c272da2e1d7                      email
# 13  0b1e1539f2cc45b7b9fa7c272da2e1d7                        web
# 16  2298d6c36e964ae4a3e7e9706d1fb8c2                      email
# 18  2298d6c36e964ae4a3e7e9706d1fb8c2                     social
# 17  2298d6c36e964ae4a3e7e9706d1fb8c2                     mobile
# 15  2298d6c36e964ae4a3e7e9706d1fb8c2                        web
# 30  2906b810c7d4411798c6938adc9daaa5                        web
# 31  2906b810c7d4411798c6938adc9daaa5                      email
# 32  2906b810c7d4411798c6938adc9daaa5                     mobile
# 9   3f207df678b143eea3cee63160fa8bed                     mobile
# 7   3f207df678b143eea3cee63160fa8bed                        web
# 8   3f207df678b143eea3cee63160fa8bed                      email
# 6   4d5c57ea9a6940dd891ad53e9dbe8da0                     social
# 5   4d5c57ea9a6940dd891ad53e9dbe8da0                     mobile
# 4   4d5c57ea9a6940dd891ad53e9dbe8da0                      email
# 3   4d5c57ea9a6940dd891ad53e9dbe8da0                        web
# 25  5a8bc65990b245e5a138643cd4eb9837                     social
# 24  5a8bc65990b245e5a138643cd4eb9837                     mobile
# 23  5a8bc65990b245e5a138643cd4eb9837                      email
# 10  9b98b8c7a33c4b65b9aebfe6a799e6d9                        web
# 11  9b98b8c7a33c4b65b9aebfe6a799e6d9                      email
# 12  9b98b8c7a33c4b65b9aebfe6a799e6d9                     mobile
# 1   ae264e3637204a6fb9bb56bc8210ddfd                     mobile
# 0   ae264e3637204a6fb9bb56bc8210ddfd                      email
# 2   ae264e3637204a6fb9bb56bc8210ddfd                     social
# 26  f19421c1d4aa40978ebb69ca19b0e20d                        web
# 27  f19421c1d4aa40978ebb69ca19b0e20d                      email
# 28  f19421c1d4aa40978ebb69ca19b0e20d                     mobile
# 29  f19421c1d4aa40978ebb69ca19b0e20d                     social
# 21  fafdcd668e3743c1bb461111dcafc2a4                     mobile
# 19  fafdcd668e3743c1bb461111dcafc2a4                        web
# 22  fafdcd668e3743c1bb461111dcafc2a4                     social
# 20  fafdcd668e3743c1bb461111dcafc2a4                      email
#
#        offer_type  offer_spend_minimum  offer_reward  offer_duration
# 14       discount                   20             5             240
# 13       discount                   20             5             240
# 16       discount                    7             3             168
# 18       discount                    7             3             168
# 17       discount                    7             3             168
# 15       discount                    7             3             168
# 30       discount                   10             2             168
# 31       discount                   10             2             168
# 32       discount                   10             2             168
# 9   informational                    0             0              96
# 7   informational                    0             0              96
# 8   informational                    0             0              96
# 6            bogo                   10            10             120
# 5            bogo                   10            10             120
# 4            bogo                   10            10             120
# 3            bogo                   10            10             120
# 25  informational                    0             0              72
# 24  informational                    0             0              72
# 23  informational                    0             0              72
# 10           bogo                    5             5             168
# 11           bogo                    5             5             168
# 12           bogo                    5             5             168
# 1            bogo                   10            10             168
# 0            bogo                   10            10             168
# 2            bogo                   10            10             168
# 26           bogo                    5             5             120
# 27           bogo                    5             5             120
# 28           bogo                    5             5             120
# 29           bogo                    5             5             120
# 21       discount                   10             2             240
# 19       discount                   10             2             240
# 22       discount                   10             2             240
# 20       discount                   10             2             240

# %%
offer_received_viewed_nocomp_agg[ (offer_received_viewed_nocomp_agg['offer_id'] == "0b1e1539f2cc45b7b9fa7c272da2e1d7") & (offer_received_viewed_nocomp_agg['user_id'] == '009d10c2c38a4fd795a7bc6ddbbddb78') ]
# Out:
#                              user_id                          offer_id  \
# 29  009d10c2c38a4fd795a7bc6ddbbddb78  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#    received_event_type viewed_event_type  offer_received_time  \
# 29      offer received      offer viewed                  168
#
#     offer_viewed_time  transaction_time  transaction_count  transaction_sum
# 29              228.0             684.0                  3              3.3

# %%
test_df = raw_interactions[ (raw_interactions['person'] == '0009655768c64bdeb2e877511632db8f') ].sort_values('time')
test_df['offer id'] = test_df['value'].apply(lambda x: x.get('offer id') if isinstance(x, dict) and 'offer id' in x else None)
test_df['offer_id'] = test_df['value'].apply(lambda x: x.get('offer_id') if isinstance(x, dict) and 'offer_id' in x else None)
# test_df = test_df[( test_df['offer id'] == '3f207df678b143eea3cee63160fa8bed') | (test_df['offer_id'] == '3f207df678b143eea3cee63160fa8bed') ]
# test_df.drop(['offer_id', 'offer id'], axis=1, inplace=True)

test_df
# Out:
#                                   person            event  \
# 55972   0009655768c64bdeb2e877511632db8f   offer received
# 77705   0009655768c64bdeb2e877511632db8f     offer viewed
# 89291   0009655768c64bdeb2e877511632db8f      transaction
# 113605  0009655768c64bdeb2e877511632db8f   offer received
# 139992  0009655768c64bdeb2e877511632db8f     offer viewed
# 153401  0009655768c64bdeb2e877511632db8f   offer received
# 168412  0009655768c64bdeb2e877511632db8f      transaction
# 168413  0009655768c64bdeb2e877511632db8f  offer completed
# 187554  0009655768c64bdeb2e877511632db8f     offer viewed
# 204340  0009655768c64bdeb2e877511632db8f   offer received
# 228422  0009655768c64bdeb2e877511632db8f      transaction
# 228423  0009655768c64bdeb2e877511632db8f  offer completed
# 233413  0009655768c64bdeb2e877511632db8f     offer viewed
# 237784  0009655768c64bdeb2e877511632db8f      transaction
# 247879  0009655768c64bdeb2e877511632db8f   offer received
# 258883  0009655768c64bdeb2e877511632db8f      transaction
# 258884  0009655768c64bdeb2e877511632db8f  offer completed
# 293497  0009655768c64bdeb2e877511632db8f      transaction
# 300930  0009655768c64bdeb2e877511632db8f      transaction
# 302205  0009655768c64bdeb2e877511632db8f      transaction
#
#                                                     value  time  \
# 55972    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   168
# 77705    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   192
# 89291                                   {'amount': 22.16}   228
# 113605   {'offer id': '3f207df678b143eea3cee63160fa8bed'}   336
# 139992   {'offer id': '3f207df678b143eea3cee63160fa8bed'}   372
# 153401   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   408
# 168412                                   {'amount': 8.57}   414
# 168413  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...   414
# 187554   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   456
# 204340   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   504
# 228422                                  {'amount': 14.11}   528
# 228423  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   528
# 233413   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   540
# 237784                                  {'amount': 13.56}   552
# 247879   {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   576
# 258883                                  {'amount': 10.27}   576
# 258884  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   576
# 293497                                  {'amount': 12.36}   660
# 300930                                  {'amount': 28.16}   690
# 302205                                  {'amount': 18.41}   696
#
#                                 offer id                          offer_id
# 55972   5a8bc65990b245e5a138643cd4eb9837                              None
# 77705   5a8bc65990b245e5a138643cd4eb9837                              None
# 89291                               None                              None
# 113605  3f207df678b143eea3cee63160fa8bed                              None
# 139992  3f207df678b143eea3cee63160fa8bed                              None
# 153401  f19421c1d4aa40978ebb69ca19b0e20d                              None
# 168412                              None                              None
# 168413                              None  f19421c1d4aa40978ebb69ca19b0e20d
# 187554  f19421c1d4aa40978ebb69ca19b0e20d                              None
# 204340  fafdcd668e3743c1bb461111dcafc2a4                              None
# 228422                              None                              None
# 228423                              None  fafdcd668e3743c1bb461111dcafc2a4
# 233413  fafdcd668e3743c1bb461111dcafc2a4                              None
# 237784                              None                              None
# 247879  2906b810c7d4411798c6938adc9daaa5                              None
# 258883                              None                              None
# 258884                              None  2906b810c7d4411798c6938adc9daaa5
# 293497                              None                              None
# 300930                              None                              None
# 302205                              None                              None

# %% [markdown]
# <a id='rvn'></a>
# ### Users that did not have transactions

# %%
offer_received_viewed_notrans = pd.merge( offer_received_viewed, transactions, on=['user_id'], how='left' )
offer_received_viewed_notrans = offer_received_viewed_notrans[ offer_received_viewed_notrans['transaction_time'].isna() ]

offer_received_viewed_notrans
# Out:
#                                  user_id received_event_type  received_time  \
# 16      8ec6ce2a7e7949b1bf142def7d0e0586      offer received              0
# 17      8ec6ce2a7e7949b1bf142def7d0e0586      offer received              0
# 623     13b7b2eccf664a329d83d2a238a9a11d      offer received              0
# 624     13b7b2eccf664a329d83d2a238a9a11d      offer received              0
# 1395    accec36a10704e1fbaeb9b28b8bc5da8      offer received              0
# ...                                  ...                 ...            ...
# 684342  0f4eeccda01547bdaa30113a09725a2b      offer received            576
# 684741  4c9c818067914caba08ca3cebadab165      offer received            576
# 684742  4c9c818067914caba08ca3cebadab165      offer received            576
# 685154  1f5e62e325d047f4833d1b7aed437f31      offer received            576
# 686037  043b6b6be98c412d901f7f376e0548d0      offer received            576
#
#                                 offer_id viewed_event_type  viewed_time  \
# 16      fafdcd668e3743c1bb461111dcafc2a4      offer viewed         12.0
# 17      fafdcd668e3743c1bb461111dcafc2a4      offer viewed        522.0
# 623     f19421c1d4aa40978ebb69ca19b0e20d      offer viewed         18.0
# 624     f19421c1d4aa40978ebb69ca19b0e20d      offer viewed        414.0
# 1395    fafdcd668e3743c1bb461111dcafc2a4      offer viewed         66.0
# ...                                  ...               ...          ...
# 684342  3f207df678b143eea3cee63160fa8bed      offer viewed        618.0
# 684741  9b98b8c7a33c4b65b9aebfe6a799e6d9      offer viewed          6.0
# 684742  9b98b8c7a33c4b65b9aebfe6a799e6d9      offer viewed        576.0
# 685154  fafdcd668e3743c1bb461111dcafc2a4      offer viewed        588.0
# 686037  2906b810c7d4411798c6938adc9daaa5      offer viewed        582.0
#
#        transaction_event_type  transaction_time  transaction_amount
# 16                        NaN               NaN                 NaN
# 17                        NaN               NaN                 NaN
# 623                       NaN               NaN                 NaN
# 624                       NaN               NaN                 NaN
# 1395                      NaN               NaN                 NaN
# ...                       ...               ...                 ...
# 684342                    NaN               NaN                 NaN
# 684741                    NaN               NaN                 NaN
# 684742                    NaN               NaN                 NaN
# 685154                    NaN               NaN                 NaN
# 686037                    NaN               NaN                 NaN
#
# [2034 rows x 9 columns]

# %% [markdown]
# <a id='rn'></a>
# ## Users that did not view offers

# %%
offer_not_viewed = pd.merge( offer_received, offer_viewed, on=['user_id', 'offer_id'], how='left' )
offer_not_viewed = offer_not_viewed[ offer_not_viewed['viewed_time'].isna() ]

display(offer_not_viewed)

# %%
user_id = '868317b9be554cb18e50bc68484749a2'
offer_id = '2906b810c7d4411798c6938adc9daaa5'

display( interactions[ (interactions['user_id'] == user_id) & (interactions['offer_id']==offer_id) ].sort_values( by=['intxn_time'] ) )
display( transactions[ transactions['user_id'] == user_id ] )
display( offers[ offers['offer_id'] == offer_id ] )

# %% [markdown]
# <a id='rnc'></a>
# ### Users that completed the offer

# %% [markdown]
# <a id='rnv'></a>
# ### Users that did not complete the offer

# %%
offer_not_completed = pd.merge( offer_viewed, offer_completed, on=['user_id', 'offer_id'], how='left' )
offer_not_completed = offer_not_completed[ offer_not_completed['completed_event_type'].isna() ]

display(offer_not_completed)

# %%
user_id = 'd1ede868e29245ea91818a903fec04c6'
offer_id = '5a8bc65990b245e5a138643cd4eb9837'

display( interactions[ (interactions['user_id'] == user_id) & (interactions['offer_id']==offer_id) ].sort_values( by=['intxn_time'] ) )
display( transactions[ transactions['user_id'] == user_id ] )
display( offers[ offers['offer_id'] == offer_id ] )

# %% [markdown]
# <a id='rnn'></a>
# ### Users that did not have transactions
